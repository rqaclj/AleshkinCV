# %% [markdown]
# ## 6 animation.ipynb

# %%
import sys
sys.path.append('..')
# Генерация анимации клеток
from src.animation import main
main()
# Out:
# ...
# Generating Animation: 100%|███████████████████████████████████████████| 240/240 [00:00<00:00, 1377.28it/s]

# %% [markdown]
# ## 3 downsampling.ipynb

# %%
import sys
sys.path.append('..')
# Даунсэмплинг изображений
from src.downsampling import main
main()
# Out:
# SSIM Max: [np.float64(0.9787096701306516), np.float64(0.9944209454169982), np.float64(0.9780928289159515), np.float64(0.9976092629866189), np.float64(0.995240002652714)]
# MSE Max: [4.6796213785807295, 3.7982584635416665, 6.6998952229817705, 2.02325439453125, 2.840123494466146]
# SSIM Median: [np.float64(0.9945356355643101), np.float64(0.9997205074317477), np.float64(0.9952280653649713), np.float64(0.9998411263035756), np.float64(0.9997511627675753)]
# MSE Median: [0.5124613444010416, 0.11942036946614583, 0.5307668050130209, 0.07436116536458333, 0.110595703125]
